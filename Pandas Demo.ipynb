# %%
import pandas as pd
data = [1,2,3,4,5]
srs = pd.Series(data, index=['a','b','c','d','e'])
print(srs)
print(type(srs))
print(srs['a':'c'])
# Out:
# a    1
# b    2
# c    3
# d    4
# e    5
# dtype: int64
# <class 'pandas.core.series.Series'>
# a    1
# b    2
# c    3
# dtype: int64

# %%
data = {"a":["apple","mango"],"b":[10,12]}
df = pd.DataFrame(data)
print(df)
# Out:
#        a   b
# 0  apple  10
# 1  mango  12

# %%
data = [1,2]
df = pd.DataFrame(data)
df.rename(index = {0:"a",1:"b"},inplace = True)
df.rename(index = str,columns={0:"A"},inplace = True)
colList = []
df.columns=["a"]
for col in df.columns:
    if col=="a":
        col="b"
    colList.append(col)
df.columns=colList
df
# Out:
#    b
# a  1
# b  2

# %%
df = pd.DataFrame({"A":[1,2,3],"B":[2,3,4]})
df
# Out:
#    A  B
# 0  1  2
# 1  2  3
# 2  3  4

# %%
df1 = pd.DataFrame({"A":[3,4,5],"C":[1,9,10]})
df1
# Out:
#    A   C
# 0  3   1
# 1  4   9
# 2  5  10

# %%
pd.concat([df,df1])
# Out:
#    A    B     C
# 0  1  2.0   NaN
# 1  2  3.0   NaN
# 2  3  4.0   NaN
# 0  3  NaN   1.0
# 1  4  NaN   9.0
# 2  5  NaN  10.0

# %%
pd.concat([df,df1],axis=1,join="inner")
# Out:
#    A  B  A   C
# 0  1  2  3   1
# 1  2  3  4   9
# 2  3  4  5  10

# %%
print(df)
print(df1)
print(pd.merge(df,df1,on=["A"],how="inner"))
# Out:
#    A  B
# 0  1  2
# 1  2  3
# 2  3  4
#    A   C
# 0  3   1
# 1  4   9
# 2  5  10
#    A  B  C
# 0  3  4  1

# %%
pd.merge(df,df1,how="right")
# Out:
#    A    B   C
# 0  3  4.0   1
# 1  4  NaN   9
# 2  5  NaN  10

# %%
pd.merge(df,df1,how="left")
# Out:
#    A  B    C
# 0  1  2  NaN
# 1  2  3  NaN
# 2  3  4  1.0

# %%
pd.merge(df,df1,how="outer")
# Out:
#    A    B     C
# 0  1  2.0   NaN
# 1  2  3.0   NaN
# 2  3  4.0   1.0
# 3  4  NaN   9.0
# 4  5  NaN  10.0

# %%
#import pandas library
import pandas as pd
#read dataset and store into a dataframe
cars=pd.read_csv(r"C:\Users\Siyavar\Downloads\archive\mtcars.csv")
#pd.read_excel(filename="",sheetname="")
#print
cars
# Out:
#                   model   mpg  cyl   disp   hp  drat     wt   qsec  vs  am  \
# 0             Mazda RX4  21.0    6  160.0  110  3.90  2.620  16.46   0   1
# 1         Mazda RX4 Wag  21.0    6  160.0  110  3.90  2.875  17.02   0   1
# 2            Datsun 710  22.8    4  108.0   93  3.85  2.320  18.61   1   1
# 3        Hornet 4 Drive  21.4    6  258.0  110  3.08  3.215  19.44   1   0
# 4     Hornet Sportabout  18.7    8  360.0  175  3.15  3.440  17.02   0   0
# 5               Valiant  18.1    6  225.0  105  2.76  3.460  20.22   1   0
# 6            Duster 360  14.3    8  360.0  245  3.21  3.570  15.84   0   0
# 7             Merc 240D  24.4    4  146.7   62  3.69  3.190  20.00   1   0
# 8              Merc 230  22.8    4  140.8   95  3.92  3.150  22.90   1   0
# 9              Merc 280  19.2    6  167.6  123  3.92  3.440  18.30   1   0
# 10            Merc 280C  17.8    6  167.6  123  3.92  3.440  18.90   1   0
# ...

# %%
#check the type
type(cars)
# Out:
# pandas.core.frame.DataFrame

# %%
#view only the first five records
cars.head()
# Out:
#                model   mpg  cyl   disp   hp  drat     wt   qsec  vs  am  gear  \
# 0          Mazda RX4  21.0    6  160.0  110  3.90  2.620  16.46   0   1     4
# 1      Mazda RX4 Wag  21.0    6  160.0  110  3.90  2.875  17.02   0   1     4
# 2         Datsun 710  22.8    4  108.0   93  3.85  2.320  18.61   1   1     4
# 3     Hornet 4 Drive  21.4    6  258.0  110  3.08  3.215  19.44   1   0     3
# 4  Hornet Sportabout  18.7    8  360.0  175  3.15  3.440  17.02   0   0     3
#
#    carb
# 0     4
# 1     4
# 2     1
# 3     1
# 4     2

# %%
#view only the fist ten records
cars.head(10)
# Out:
#                model   mpg  cyl   disp   hp  drat     wt   qsec  vs  am  gear  \
# 0          Mazda RX4  21.0    6  160.0  110  3.90  2.620  16.46   0   1     4
# 1      Mazda RX4 Wag  21.0    6  160.0  110  3.90  2.875  17.02   0   1     4
# 2         Datsun 710  22.8    4  108.0   93  3.85  2.320  18.61   1   1     4
# 3     Hornet 4 Drive  21.4    6  258.0  110  3.08  3.215  19.44   1   0     3
# 4  Hornet Sportabout  18.7    8  360.0  175  3.15  3.440  17.02   0   0     3
# 5            Valiant  18.1    6  225.0  105  2.76  3.460  20.22   1   0     3
# 6         Duster 360  14.3    8  360.0  245  3.21  3.570  15.84   0   0     3
# 7          Merc 240D  24.4    4  146.7   62  3.69  3.190  20.00   1   0     4
# 8           Merc 230  22.8    4  140.8   95  3.92  3.150  22.90   1   0     4
# 9           Merc 280  19.2    6  167.6  123  3.92  3.440  18.30   1   0     4
#
#    carb
# 0     4
# 1     4
# 2     1
# 3     1
# 4     2
# 5     1
# 6     4
# 7     2
# 8     2
# 9     4

# %%
#view only the last five records
cars.tail()
# Out:
#              model   mpg  cyl   disp   hp  drat     wt  qsec  vs  am  gear  \
# 27    Lotus Europa  30.4    4   95.1  113  3.77  1.513  16.9   1   1     5
# 28  Ford Pantera L  15.8    8  351.0  264  4.22  3.170  14.5   0   1     5
# 29    Ferrari Dino  19.7    6  145.0  175  3.62  2.770  15.5   0   1     5
# 30   Maserati Bora  15.0    8  301.0  335  3.54  3.570  14.6   0   1     5
# 31      Volvo 142E  21.4    4  121.0  109  4.11  2.780  18.6   1   1     4
#
#     carb
# 27     2
# 28     4
# 29     6
# 30     8
# 31     2

# %%
#view only the last ten records
cars.tail(10)
# Out:
#                model   mpg  cyl   disp   hp  drat     wt   qsec  vs  am  gear  \
# 22       AMC Javelin  15.2    8  304.0  150  3.15  3.435  17.30   0   0     3
# 23        Camaro Z28  13.3    8  350.0  245  3.73  3.840  15.41   0   0     3
# 24  Pontiac Firebird  19.2    8  400.0  175  3.08  3.845  17.05   0   0     3
# 25         Fiat X1-9  27.3    4   79.0   66  4.08  1.935  18.90   1   1     4
# 26     Porsche 914-2  26.0    4  120.3   91  4.43  2.140  16.70   0   1     5
# 27      Lotus Europa  30.4    4   95.1  113  3.77  1.513  16.90   1   1     5
# 28    Ford Pantera L  15.8    8  351.0  264  4.22  3.170  14.50   0   1     5
# 29      Ferrari Dino  19.7    6  145.0  175  3.62  2.770  15.50   0   1     5
# 30     Maserati Bora  15.0    8  301.0  335  3.54  3.570  14.60   0   1     5
# 31        Volvo 142E  21.4    4  121.0  109  4.11  2.780  18.60   1   1     4
#
#     carb
# 22     2
# 23     4
# 24     2
# 25     1
# 26     2
# 27     2
# 28     4
# 29     6
# 30     8
# ...

# %%
#view number of rows and columns in the dataframe
cars.shape
# Out:
# (32, 12)

# %%
#print a concise summary of the columns
cars.info(null_counts=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32 entries, 0 to 31
# Data columns (total 12 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   model   32 non-null     object
#  1   mpg     32 non-null     float64
#  2   cyl     32 non-null     int64
#  3   disp    32 non-null     float64
#  4   hp      32 non-null     int64
#  5   drat    32 non-null     float64
#  6   wt      32 non-null     float64
#  7   qsec    32 non-null     float64
#  8   vs      32 non-null     int64
#  9   am      32 non-null     int64
#  10  gear    32 non-null     int64
#  11  carb    32 non-null     int64
# dtypes: float64(5), int64(6), object(1)
# memory usage: 3.1+ KB
# <ipython-input-124-cba1b17e7c8d>:2: FutureWarning: null_counts is deprecated. Use show_counts instead
#   cars.info(null_counts=True)

# %%
#mean
cars.mean()
# Out:
# mpg      20.090625
# cyl       6.187500
# disp    230.721875
# hp      146.687500
# drat      3.596563
# wt        3.217250
# qsec     17.848750
# vs        0.437500
# am        0.406250
# gear      3.687500
# carb      2.812500
# dtype: float64

# %%
#median
cars.median()
# Out:
# mpg      19.200
# cyl       6.000
# disp    196.300
# hp      123.000
# drat      3.695
# wt        3.325
# qsec     17.710
# vs        0.000
# am        0.000
# gear      4.000
# carb      2.000
# dtype: float64

# %%
#standard deviation
cars.std()
# Out:
# mpg       6.026948
# cyl       1.785922
# disp    123.938694
# hp       68.562868
# drat      0.534679
# wt        0.978457
# qsec      1.786943
# vs        0.504016
# am        0.498991
# gear      0.737804
# carb      1.615200
# dtype: float64

# %%
#maximum of each attribute
cars.max()
# Out:
# model    Volvo 142E
# mpg          33.900
# cyl               8
# disp        472.000
# hp              335
# drat          4.930
# wt            5.424
# qsec         22.900
# vs                1
# am                1
# gear              5
# carb              8
# dtype: object

# %%
#minimum of each attribute
cars.min()
# Out:
# model    AMC Javelin
# mpg           10.400
# cyl                4
# disp          71.100
# hp                52
# drat           2.760
# wt             1.513
# qsec          14.500
# vs                 0
# am                 0
# gear               3
# carb               1
# dtype: object

# %%
#number of non-null records in each column
cars.count()
# Out:
# model    32
# mpg      32
# cyl      32
# disp     32
# hp       32
# drat     32
# wt       32
# qsec     32
# vs       32
# am       32
# gear     32
# carb     32
# dtype: int64

# %%
#descriptive statistics summary
cars.describe()
# Out:
#              mpg        cyl        disp          hp       drat         wt  \
# count  32.000000  32.000000   32.000000   32.000000  32.000000  32.000000
# mean   20.090625   6.187500  230.721875  146.687500   3.596563   3.217250
# std     6.026948   1.785922  123.938694   68.562868   0.534679   0.978457
# min    10.400000   4.000000   71.100000   52.000000   2.760000   1.513000
# 25%    15.425000   4.000000  120.825000   96.500000   3.080000   2.581250
# 50%    19.200000   6.000000  196.300000  123.000000   3.695000   3.325000
# 75%    22.800000   8.000000  326.000000  180.000000   3.920000   3.610000
# max    33.900000   8.000000  472.000000  335.000000   4.930000   5.424000
#
#             qsec         vs         am       gear     carb
# count  32.000000  32.000000  32.000000  32.000000  32.0000
# mean   17.848750   0.437500   0.406250   3.687500   2.8125
# std     1.786943   0.504016   0.498991   0.737804   1.6152
# min    14.500000   0.000000   0.000000   3.000000   1.0000
# ...

# %%
#rename column
cars=cars.rename(columns={'Unnamed: 1':'model'})
cars
# Out:
#                   model   mpg  cyl   disp   hp  drat     wt   qsec  vs  am  \
# 0             Mazda RX4  21.0    6  160.0  110  3.90  2.620  16.46   0   1
# 1         Mazda RX4 Wag  21.0    6  160.0  110  3.90  2.875  17.02   0   1
# 2            Datsun 710  22.8    4  108.0   93  3.85  2.320  18.61   1   1
# 3        Hornet 4 Drive  21.4    6  258.0  110  3.08  3.215  19.44   1   0
# 4     Hornet Sportabout  18.7    8  360.0  175  3.15  3.440  17.02   0   0
# 5               Valiant  18.1    6  225.0  105  2.76  3.460  20.22   1   0
# 6            Duster 360  14.3    8  360.0  245  3.21  3.570  15.84   0   0
# 7             Merc 240D  24.4    4  146.7   62  3.69  3.190  20.00   1   0
# 8              Merc 230  22.8    4  140.8   95  3.92  3.150  22.90   1   0
# 9              Merc 280  19.2    6  167.6  123  3.92  3.440  18.30   1   0
# 10            Merc 280C  17.8    6  167.6  123  3.92  3.440  18.90   1   0
# ...

# %%
#fill the null values with mean of the column
#cars.qsec=cars.qsec.fillna(cars.qsec.mean())
#cars

# %%
#drop unwanted column
#cars = cars.drop(columns=['S.No'])
#cars

# %%
#find correlation matrix
df=cars[['mpg','cyl','disp','hp','drat','wt','qsec','vs','am','gear','carb']].corr()
df
#you can see mpg is of string type so we can't perform correlation
# Out:
#            mpg       cyl      disp        hp      drat        wt      qsec  \
# mpg   1.000000 -0.852162 -0.847551 -0.776168  0.681172 -0.867659  0.418684
# cyl  -0.852162  1.000000  0.902033  0.832447 -0.699938  0.782496 -0.591242
# disp -0.847551  0.902033  1.000000  0.790949 -0.710214  0.887980 -0.433698
# hp   -0.776168  0.832447  0.790949  1.000000 -0.448759  0.658748 -0.708223
# drat  0.681172 -0.699938 -0.710214 -0.448759  1.000000 -0.712441  0.091205
# wt   -0.867659  0.782496  0.887980  0.658748 -0.712441  1.000000 -0.174716
# qsec  0.418684 -0.591242 -0.433698 -0.708223  0.091205 -0.174716  1.000000
# vs    0.664039 -0.810812 -0.710416 -0.723097  0.440278 -0.554916  0.744535
# am    0.599832 -0.522607 -0.591227 -0.243204  0.712711 -0.692495 -0.229861
# gear  0.480285 -0.492687 -0.555569 -0.125704  0.699610 -0.583287 -0.212682
# carb -0.550925  0.526988  0.394977  0.749812 -0.090790  0.427606 -0.656249
#
#             vs        am      gear      carb
# ...

# %%
#view hp column only
cars.iloc[:,4]
# Out:
# 0     110
# 1     110
# 2      93
# 3     110
# 4     175
# 5     105
# 6     245
# 7      62
# 8      95
# 9     123
# 10    123
# 11    180
# 12    180
# 13    180
# 14    205
# 15    215
# 16    230
# 17     66
# 18     52
# 19     65
# 20     97
# 21    150
# 22    150
# 23    245
# 24    175
# 25     66
# 26     91
# 27    113
# 28    264
# 29    175
# 30    335
# 31    109
# Name: hp, dtype: int64

# %%
#first five records of hp column
cars.iloc[0:5,4]
# Out:
# 0    110
# 1    110
# 2     93
# 3    110
# 4    175
# Name: hp, dtype: int64

# %%
#all rows and columns
cars.iloc[:,:]
# Out:
#                   model   mpg  cyl   disp   hp  drat     wt   qsec  vs  am  \
# 0             Mazda RX4  21.0    6  160.0  110  3.90  2.620  16.46   0   1
# 1         Mazda RX4 Wag  21.0    6  160.0  110  3.90  2.875  17.02   0   1
# 2            Datsun 710  22.8    4  108.0   93  3.85  2.320  18.61   1   1
# 3        Hornet 4 Drive  21.4    6  258.0  110  3.08  3.215  19.44   1   0
# 4     Hornet Sportabout  18.7    8  360.0  175  3.15  3.440  17.02   0   0
# 5               Valiant  18.1    6  225.0  105  2.76  3.460  20.22   1   0
# 6            Duster 360  14.3    8  360.0  245  3.21  3.570  15.84   0   0
# 7             Merc 240D  24.4    4  146.7   62  3.69  3.190  20.00   1   0
# 8              Merc 230  22.8    4  140.8   95  3.92  3.150  22.90   1   0
# 9              Merc 280  19.2    6  167.6  123  3.92  3.440  18.30   1   0
# 10            Merc 280C  17.8    6  167.6  123  3.92  3.440  18.90   1   0
# ...

# %%
#for attributes from hp to carb see all records from index 6
cars.iloc[6:,4:]
# Out:
#      hp  drat     wt   qsec  vs  am  gear  carb
# 6   245  3.21  3.570  15.84   0   0     3     4
# 7    62  3.69  3.190  20.00   1   0     4     2
# 8    95  3.92  3.150  22.90   1   0     4     2
# 9   123  3.92  3.440  18.30   1   0     4     4
# 10  123  3.92  3.440  18.90   1   0     4     4
# 11  180  3.07  4.070  17.40   0   0     3     3
# 12  180  3.07  3.730  17.60   0   0     3     3
# 13  180  3.07  3.780  18.00   0   0     3     3
# 14  205  2.93  5.250  17.98   0   0     3     4
# 15  215  3.00  5.424  17.82   0   0     3     4
# 16  230  3.23  5.345  17.42   0   0     3     4
# 17   66  4.08  2.200  19.47   1   1     4     1
# 18   52  4.93  1.615  18.52   1   1     4     2
# 19   65  4.22  1.835  19.90   1   1     4     1
# 20   97  3.70  2.465  20.01   1   0     3     1
# 21  150  2.76  3.520  16.87   0   0     3     2
# 22  150  3.15  3.435  17.30   0   0     3     2
# 23  245  3.73  3.840  15.41   0   0     3     4
# 24  175  3.08  3.845  17.05   0   0     3     2
# ...

# %%
#now we want to look at all the rows and only the first column
cars.iloc[:,1]
# Out:
# 0     21.0
# 1     21.0
# 2     22.8
# 3     21.4
# 4     18.7
# 5     18.1
# 6     14.3
# 7     24.4
# 8     22.8
# 9     19.2
# 10    17.8
# 11    16.4
# 12    17.3
# 13    15.2
# 14    10.4
# 15    10.4
# 16    14.7
# 17    32.4
# 18    30.4
# 19    33.9
# 20    21.5
# 21    15.5
# 22    15.2
# 23    13.3
# 24    19.2
# 25    27.3
# 26    26.0
# 27    30.4
# 28    15.8
# 29    19.7
# 30    15.0
# 31    21.4
# Name: mpg, dtype: float64

# %%
#see all the records of mpg column
cars.loc[:,"mpg"]
# Out:
# 0     21.0
# 1     21.0
# 2     22.8
# 3     21.4
# 4     18.7
# 5     18.1
# 6     14.3
# 7     24.4
# 8     22.8
# 9     19.2
# 10    17.8
# 11    16.4
# 12    17.3
# 13    15.2
# 14    10.4
# 15    10.4
# 16    14.7
# 17    32.4
# 18    30.4
# 19    33.9
# 20    21.5
# 21    15.5
# 22    15.2
# 23    13.3
# 24    19.2
# 25    27.3
# 26    26.0
# 27    30.4
# 28    15.8
# 29    19.7
# 30    15.0
# 31    21.4
# Name: mpg, dtype: float64

# %%
#display the records from index 0 to index 6 from mpg column
cars.loc[:6,"mpg"]
# Out:
# 0    21.0
# 1    21.0
# 2    22.8
# 3    21.4
# 4    18.7
# 5    18.1
# 6    14.3
# Name: mpg, dtype: float64

# %%
#see the first 7 records from mpg to qsec column
cars.loc[:6,"mpg":"qsec"]
# Out:
#     mpg  cyl   disp   hp  drat     wt   qsec
# 0  21.0    6  160.0  110  3.90  2.620  16.46
# 1  21.0    6  160.0  110  3.90  2.875  17.02
# 2  22.8    4  108.0   93  3.85  2.320  18.61
# 3  21.4    6  258.0  110  3.08  3.215  19.44
# 4  18.7    8  360.0  175  3.15  3.440  17.02
# 5  18.1    6  225.0  105  2.76  3.460  20.22
# 6  14.3    8  360.0  245  3.21  3.570  15.84

# %%
#set value 1 to column 'am' to 1
cars['am'] = 1
cars
# Out:
#                   model   mpg  cyl   disp   hp  drat     wt   qsec  vs  am  \
# 0             Mazda RX4  21.0    6  160.0  110  3.90  2.620  16.46   0   1
# 1         Mazda RX4 Wag  21.0    6  160.0  110  3.90  2.875  17.02   0   1
# 2            Datsun 710  22.8    4  108.0   93  3.85  2.320  18.61   1   1
# 3        Hornet 4 Drive  21.4    6  258.0  110  3.08  3.215  19.44   1   1
# 4     Hornet Sportabout  18.7    8  360.0  175  3.15  3.440  17.02   0   1
# 5               Valiant  18.1    6  225.0  105  2.76  3.460  20.22   1   1
# 6            Duster 360  14.3    8  360.0  245  3.21  3.570  15.84   0   1
# 7             Merc 240D  24.4    4  146.7   62  3.69  3.190  20.00   1   1
# 8              Merc 230  22.8    4  140.8   95  3.92  3.150  22.90   1   1
# 9              Merc 280  19.2    6  167.6  123  3.92  3.440  18.30   1   1
# 10            Merc 280C  17.8    6  167.6  123  3.92  3.440  18.90   1   1
# ...

# %%
#double up records in 'am' using lambda function
f = lambda x: x*2
cars['am']=cars['am'].apply(f)
cars
# Out:
#                   model   mpg  cyl   disp   hp  drat     wt   qsec  vs  am  \
# 0             Mazda RX4  21.0    6  160.0  110  3.90  2.620  16.46   0   2
# 1         Mazda RX4 Wag  21.0    6  160.0  110  3.90  2.875  17.02   0   2
# 2            Datsun 710  22.8    4  108.0   93  3.85  2.320  18.61   1   2
# 3        Hornet 4 Drive  21.4    6  258.0  110  3.08  3.215  19.44   1   2
# 4     Hornet Sportabout  18.7    8  360.0  175  3.15  3.440  17.02   0   2
# 5               Valiant  18.1    6  225.0  105  2.76  3.460  20.22   1   2
# 6            Duster 360  14.3    8  360.0  245  3.21  3.570  15.84   0   2
# 7             Merc 240D  24.4    4  146.7   62  3.69  3.190  20.00   1   2
# 8              Merc 230  22.8    4  140.8   95  3.92  3.150  22.90   1   2
# 9              Merc 280  19.2    6  167.6  123  3.92  3.440  18.30   1   2
# 10            Merc 280C  17.8    6  167.6  123  3.92  3.440  18.90   1   2
# ...

# %%
cars
# Out:
#                   model   mpg  cyl   disp   hp  drat     wt   qsec  vs  am  \
# 0             Mazda RX4  21.0    6  160.0  110  3.90  2.620  16.46   0   2
# 1         Mazda RX4 Wag  21.0    6  160.0  110  3.90  2.875  17.02   0   2
# 2            Datsun 710  22.8    4  108.0   93  3.85  2.320  18.61   1   2
# 3        Hornet 4 Drive  21.4    6  258.0  110  3.08  3.215  19.44   1   2
# 4     Hornet Sportabout  18.7    8  360.0  175  3.15  3.440  17.02   0   2
# 5               Valiant  18.1    6  225.0  105  2.76  3.460  20.22   1   2
# 6            Duster 360  14.3    8  360.0  245  3.21  3.570  15.84   0   2
# 7             Merc 240D  24.4    4  146.7   62  3.69  3.190  20.00   1   2
# 8              Merc 230  22.8    4  140.8   95  3.92  3.150  22.90   1   2
# 9              Merc 280  19.2    6  167.6  123  3.92  3.440  18.30   1   2
# 10            Merc 280C  17.8    6  167.6  123  3.92  3.440  18.90   1   2
# ...

# %%
cars['am'] = 2
cars
# Out:
#                   model   mpg  cyl   disp   hp  drat     wt   qsec  vs  am  \
# 0             Mazda RX4  21.0    6  160.0  110  3.90  2.620  16.46   0   2
# 1         Mazda RX4 Wag  21.0    6  160.0  110  3.90  2.875  17.02   0   2
# 2            Datsun 710  22.8    4  108.0   93  3.85  2.320  18.61   1   2
# 3        Hornet 4 Drive  21.4    6  258.0  110  3.08  3.215  19.44   1   2
# 4     Hornet Sportabout  18.7    8  360.0  175  3.15  3.440  17.02   0   2
# 5               Valiant  18.1    6  225.0  105  2.76  3.460  20.22   1   2
# 6            Duster 360  14.3    8  360.0  245  3.21  3.570  15.84   0   2
# 7             Merc 240D  24.4    4  146.7   62  3.69  3.190  20.00   1   2
# 8              Merc 230  22.8    4  140.8   95  3.92  3.150  22.90   1   2
# 9              Merc 280  19.2    6  167.6  123  3.92  3.440  18.30   1   2
# 10            Merc 280C  17.8    6  167.6  123  3.92  3.440  18.90   1   2
# ...

# %%
#sorting cyl column ascending order
cars.sort_values(by='cyl')
# Out:
#                   model   mpg  cyl   disp   hp  drat     wt   qsec  vs  am  \
# 31           Volvo 142E  21.4    4  121.0  109  4.11  2.780  18.60   1   2
# 2            Datsun 710  22.8    4  108.0   93  3.85  2.320  18.61   1   2
# 27         Lotus Europa  30.4    4   95.1  113  3.77  1.513  16.90   1   2
# 26        Porsche 914-2  26.0    4  120.3   91  4.43  2.140  16.70   0   2
# 25            Fiat X1-9  27.3    4   79.0   66  4.08  1.935  18.90   1   2
# 20        Toyota Corona  21.5    4  120.1   97  3.70  2.465  20.01   1   2
# 7             Merc 240D  24.4    4  146.7   62  3.69  3.190  20.00   1   2
# 8              Merc 230  22.8    4  140.8   95  3.92  3.150  22.90   1   2
# 19       Toyota Corolla  33.9    4   71.1   65  4.22  1.835  19.90   1   2
# 18          Honda Civic  30.4    4   75.7   52  4.93  1.615  18.52   1   2
# 17             Fiat 128  32.4    4   78.7   66  4.08  2.200  19.47   1   2
# ...

# %%
#sorting cyl column in descending order
cars.sort_values(by='cyl',ascending=False)
# Out:
#                   model   mpg  cyl   disp   hp  drat     wt   qsec  vs  am  \
# 16    Chrysler Imperial  14.7    8  440.0  230  3.23  5.345  17.42   0   2
# 30        Maserati Bora  15.0    8  301.0  335  3.54  3.570  14.60   0   2
# 4     Hornet Sportabout  18.7    8  360.0  175  3.15  3.440  17.02   0   2
# 28       Ford Pantera L  15.8    8  351.0  264  4.22  3.170  14.50   0   2
# 6            Duster 360  14.3    8  360.0  245  3.21  3.570  15.84   0   2
# 24     Pontiac Firebird  19.2    8  400.0  175  3.08  3.845  17.05   0   2
# 23           Camaro Z28  13.3    8  350.0  245  3.73  3.840  15.41   0   2
# 22          AMC Javelin  15.2    8  304.0  150  3.15  3.435  17.30   0   2
# 21     Dodge Challenger  15.5    8  318.0  150  2.76  3.520  16.87   0   2
# 11           Merc 450SE  16.4    8  275.8  180  3.07  4.070  17.40   0   2
# 12           Merc 450SL  17.3    8  275.8  180  3.07  3.730  17.60   0   2
# ...

# %%
#filter records with more than 6 cylinders
cars['cyl']>6
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4      True
# 5     False
# 6      True
# 7     False
# 8     False
# 9     False
# 10    False
# 11     True
# 12     True
# 13     True
# 14     True
# 15     True
# 16     True
# 17    False
# 18    False
# 19    False
# 20    False
# 21     True
# 22     True
# 23     True
# 24     True
# 25    False
# 26    False
# 27    False
# 28     True
# 29    False
# 30     True
# 31    False
# Name: cyl, dtype: bool

# %%
#filtered records with more than 6 cylinders
filter1 = cars['cyl'] > 6
#apply filter to dataframe
filtered_new = cars[filter1]
#view filtered dataframe
filtered_new
# Out:
#                   model   mpg  cyl   disp   hp  drat     wt   qsec  vs  am  \
# 4     Hornet Sportabout  18.7    8  360.0  175  3.15  3.440  17.02   0   2
# 6            Duster 360  14.3    8  360.0  245  3.21  3.570  15.84   0   2
# 11           Merc 450SE  16.4    8  275.8  180  3.07  4.070  17.40   0   2
# 12           Merc 450SL  17.3    8  275.8  180  3.07  3.730  17.60   0   2
# 13          Merc 450SLC  15.2    8  275.8  180  3.07  3.780  18.00   0   2
# 14   Cadillac Fleetwood  10.4    8  472.0  205  2.93  5.250  17.98   0   2
# 15  Lincoln Continental  10.4    8  460.0  215  3.00  5.424  17.82   0   2
# 16    Chrysler Imperial  14.7    8  440.0  230  3.23  5.345  17.42   0   2
# 21     Dodge Challenger  15.5    8  318.0  150  2.76  3.520  16.87   0   2
# 22          AMC Javelin  15.2    8  304.0  150  3.15  3.435  17.30   0   2
# 23           Camaro Z28  13.3    8  350.0  245  3.73  3.840  15.41   0   2
# ...

# %%
#filtered records with more than 6 cylinders and hp more than 300
filter2 = (cars['cyl'] > 6) & (cars['hp'] > 300)
#apply filter to dataframe
filtered_review = cars[filter2]
#view filtered dataframe
filtered_review
# Out:
#             model   mpg  cyl   disp   hp  drat    wt  qsec  vs  am  gear  carb
# 30  Maserati Bora  15.0    8  301.0  335  3.54  3.57  14.6   0   2     5     8

# %%
#import matplotlib
import matplotlib.pyplot as plt
# %matplotlib inline
#see how hp varies with each car with line plot
y1 = cars['hp']
x = range(32)
plt.plot(x,y1)

# %%
#import matplotlib
import matplotlib.pyplot as plt
# %matplotlib inline
#see how disp varies with each car with line plot
y2 = cars['disp']
x = range(32)
plt.plot(x,y2)

# %%
#import matplotlib
import matplotlib.pyplot as plt
# %matplotlib inline
y1 = cars['hp']
y2 = cars['disp']
#see how both hp and disp varies
x = range(32)
plt.plot(x,y1)
plt.plot(x,y2)
plt.legend()
# Out:
# No handles with labels found to put in legend.

# %%
#import matplotlib
import matplotlib.pyplot as plt
# %matplotlib inline
y1 = cars['hp']
y2 = cars['disp']
x = range(32)
#arae plot of hp and disp
plt.stackplot(x,y1,alpha=1,color='orange')
plt.stackplot(x,y2,alpha=0.5,color='green')

# %%
#import matplotlib
import matplotlib.pyplot as plt
# %matplotlib inline
y1 = cars['hp']
y2 = cars['disp']
x = range(32)
#plot both line plot and area plot to see the margin
plt.plot(x,y1, linewidth=2.0,color='c')
plt.stackplot(x,y1,alpha=0.7,color='purple')
plt.plot(x,y2, linewidth=1.0,color='r')
plt.stackplot(x,y2,alpha=0.5,color='black')

# %%
#import matplotlib
import matplotlib.pyplot as plt
# %matplotlib inline
y = cars['hp']
x = range(32)
#model to list
x1 = cars['model'].tolist()
#adding figure to adjust figsize
fig = plt.figure(figsize=(30,15))
#see how hp changes with bar plot
plt.bar(x1,y,color="purple", alpha=0.9)
# Out:
# <BarContainer object of 32 artists>

# %%
#import matplotlib
import matplotlib.pyplot as plt
# %matplotlib inline
y = cars['hp']
x = range(32)
#model to list
x1 = cars['model'].tolist()
#adding figure to adjust figsize
fig = plt.figure(figsize=(17,10))
#see how hp changes with bar plot
plt.barh(x1,y,color="purple", alpha=0.8)
# Out:
# <BarContainer object of 32 artists>
